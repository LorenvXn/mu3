# %%
! cat /home/hehe/huehue.py
# Out:
# #!/usr/bin/python3
#
# import os, sys
# import argparse
# import json
#
# from collections import namedtuple
# from ansible.parsing.dataloader import DataLoader
# from ansible.vars.manager import VariableManager
# from ansible.playbook.play import Play
# from ansible.inventory.manager import InventoryManager
# from ansible.utils.vars import load_extra_vars
# from ansible.executor.task_queue_manager import TaskQueueManager
#
# from ansible.playbook.helpers import load_list_of_tasks
#
#
# Options = namedtuple('Opions',
#                    ['listtags',
# 		    'listtasks',
#                     'listhosts',
#  		    'syntax',
#                     'connection',
# 		    'module_path',
# 		    'forks',
# 		    'remote_user',
#                     'private_key_file',
# 		    'ssh_common_args',
# 		    'ssh_extra_args',
# 		    'sftp_extra_args',
#                     'scp_extra_args',
# 		    'become',
#                     'become_method',
#                     'become_user',
# ...

# %%
! python huehue.py "{ \"weather\" : \"news\" }"
# Out:
# PLAY [check contain file] ******************************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [192.168.0.18]
#
# TASK [shell] *******************************************************************
# changed: [192.168.0.18]
#
# TASK [debug] *******************************************************************
# ok: [192.168.0.18] => {
#     "msg": "Check out the weather!"
# }
#
# PLAY [check file content before replacement] ***********************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [192.168.0.18]
#
# TASK [replace] *****************************************************************
# changed: [192.168.0.18]
#
# PLAY [check file content after replacement] ************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [192.168.0.18]
#
# ...
